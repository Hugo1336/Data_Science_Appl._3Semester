# %%
from textblob import TextBlob
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from string import punctuation

PUNCTUATIONS = punctuation + "“”‘’—–"

from text_magic.functions import pipeline
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from textblob import TextBlob
#       2 from nltk.corpus import stopwords
#       3 from nltk.stem import PorterStemmer
#
# File c:\Users\Julian\OneDrive - FH Vorarlberg\Dokumente\Github Repos\Data_Science_Appl._3Semester\.venv\Lib\site-packages\textblob\__init__.py:1
# ----> 1 from .blob import Blobber, Sentence, TextBlob, Word, WordList
#       3 __all__ = [
#       4     "TextBlob",
#       5     "Word",
#    (...)      8     "WordList",
#       9 ]
#
# File c:\Users\Julian\OneDrive - FH Vorarlberg\Dokumente\Github Repos\Data_Science_Appl._3Semester\.venv\Lib\site-packages\textblob\blob.py:27
#      24 import sys
#      25 from collections import defaultdict
# ---> 27 import nltk
#      29 from textblob.base import (
#      30     BaseNPExtractor,
#      31     BaseParser,
#    (...)     34     BaseTokenizer,
#      35 )
#      36 from textblob.decorators import cached_property, requires_nltk_corpus
#
# File c:\Users\Julian\OneDrive - FH Vorarlberg\Dokumente\Github Repos\Data_Science_Appl._3Semester\.venv\Lib\site-packages\nltk\__init__.py:180
#     177 else:
#     178     from nltk import cluster
# --> 180 from nltk.downloader import download, download_shell
#     182 # Check if tkinter exists without importing it to avoid crashes after
#     183 # forks on macOS. Only nltk.app, nltk.draw, and demo modules should
#     184 # have top-level tkinter imports. See #2949 for more details.
#     185 if importlib.util.find_spec("tkinter"):
#
# File c:\Users\Julian\OneDrive - FH Vorarlberg\Dokumente\Github Repos\Data_Science_Appl._3Semester\.venv\Lib\site-packages\nltk\downloader.py:2528
#    2518             pass
#    2521 ######################################################################
#    2522 # Main:
#    2523 ######################################################################
#    (...)   2526
#    2527 # Aliases
# -> 2528 _downloader = Downloader()
#    2529 download = _downloader.download
#    2532 def download_shell():
#
# File c:\Users\Julian\OneDrive - FH Vorarlberg\Dokumente\Github Repos\Data_Science_Appl._3Semester\.venv\Lib\site-packages\nltk\downloader.py:503, in Downloader.__init__(self, server_index_url, download_dir)
#     501 # decide where we're going to save things to.
#     502 if self._download_dir is None:
# --> 503     self._download_dir = self.default_download_dir()
#
# File c:\Users\Julian\OneDrive - FH Vorarlberg\Dokumente\Github Repos\Data_Science_Appl._3Semester\.venv\Lib\site-packages\nltk\downloader.py:1056, in Downloader.default_download_dir(self)
#    1052     return
#    1054 # Check if we have sufficient permissions to install in a
#    1055 # variety of system-wide locations.
# -> 1056 for nltkdir in nltk.data.path:
#    1057     if os.path.exists(nltkdir) and nltk.internals.is_writable(nltkdir):
#    1058         return nltkdir
#
# AttributeError: partially initialized module 'nltk' from 'c:\Users\Julian\OneDrive - FH Vorarlberg\Dokumente\Github Repos\Data_Science_Appl._3Semester\.venv\Lib\site-packages\nltk\__init__.py' has no attribute 'data' (most likely due to a circular import)

# %%
with open(file = "quotes/quote_1_0.txt", mode="r", encoding="utf-8") as file:
    text1 = file.read()

# %%
text1
# Out:
# 'The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.'

# %%
text = "Das Wetter ist heute schön."

# %%
text
# Out:
# 'Das Wetter ist heute schön.'

# %%
text1 = pipeline(text1)
print(text1)
# Out:
# the world as we have created it is a process of our thinking it cannot be changed without changing our thinking

# %%
clean_to_lower("Hello Welt")
# Out:
# 'hello welt'

# %%
text1 = clean_to_lower(text1)

# %%
clean_punctuation(text1)
# Out:
# 'the world as we have created it is a process of our thinking it cannot be changed without changing our thinking'

# %%
clean_strip('\nthe world.     as we have created ')
# Out:
# 'the world. as we have created'

# %%
#Nebenschauplatz

# %%
from nltk.corpus import stopwords
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from nltk.corpus import stopwords
#
# File c:\Users\Julian\OneDrive - FH Vorarlberg\Dokumente\Github Repos\Data_Science_Appl._3Semester\.venv\Lib\site-packages\nltk\corpus\__init__.py:64
#       9 """
#      10 NLTK corpus readers.  The modules in this package provide functions
#      11 that can be used to read corpus files in a variety of formats.  These
#    (...)     59
#      60 """
#      62 import re
# ---> 64 from nltk.corpus.reader import *
#      65 from nltk.corpus.util import LazyCorpusLoader
#      66 from nltk.tokenize import RegexpTokenizer
#
# File c:\Users\Julian\OneDrive - FH Vorarlberg\Dokumente\Github Repos\Data_Science_Appl._3Semester\.venv\Lib\site-packages\nltk\corpus\reader\__init__.py:57
#       1 # Natural Language Toolkit: Corpus Readers
#       2 #
#       3 # Copyright (C) 2001-2025 NLTK Project
#    (...)      6 # URL: <https://www.nltk.org/>
#       7 # For license information, see LICENSE.TXT
#       9 """
#      10 NLTK corpus readers.  The modules in this package provide functions
#      11 that can be used to read corpus fileids in a variety of formats.  These
#    (...)     54 isort:skip_file
#      55 """
# ---> 57 from nltk.corpus.reader.plaintext import *
#      58 from nltk.corpus.reader.util import *
#      59 from nltk.corpus.reader.api import *
#
# File c:\Users\Julian\OneDrive - FH Vorarlberg\Dokumente\Github Repos\Data_Science_Appl._3Semester\.venv\Lib\site-packages\nltk\corpus\reader\plaintext.py:14
#       1 # Natural Language Toolkit: Plaintext Corpus Reader
#       2 #
#       3 # Copyright (C) 2001-2025 NLTK Project
#    (...)      7 # URL: <https://www.nltk.org/>
#       8 # For license information, see LICENSE.TXT
#      10 """
#      11 A reader for corpora that consist of plaintext documents.
#      12 """
# ---> 14 import nltk.data
#      15 from nltk.corpus.reader.api import *
#      16 from nltk.corpus.reader.util import *
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1337, in _find_and_load_unlocked(name, import_)
#
# KeyError: 'nltk'
